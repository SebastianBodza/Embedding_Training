# %%
import pandas as pd 
df = pd.read_parquet("results.parquet")

def parse_text(text): 
    topics = text.split("\n\n")

    data = []

    for topic in topics: 
        if topic: 
            title, *questions = topic.split("\n")
            title = title.removesuffix("':").removeprefix("'")
            questions = [question.split(". ",1)[1].removesuffix('"').removeprefix('"') if ". " in question else question for question in questions]
            data.append({"topic": title, "questions": questions})
    return pd.DataFrame(data)

df_parsed = pd.concat(df["results"].apply(parse_text).tolist(), ignore_index=True)

num_questions = df_parsed["questions"].apply(len).sum()
print(f"Generated {num_questions} questions")
df_parsed
# Out:
# Generated 76761 questions
#                     topic                                          questions
# 0      Star-Wars-Universe  [Suche nach Filmen, in denen Darth Vader vorko...
# 1      Heißwassererhitzer  [Suche nach Anleitungen zur Installation von B...
# 2             Nagelpflege  [Suche nach Videotutorials zur Maniküre und Pe...
# 3              Großbetrug  [Suche nach Nachrichtenartikeln über Wirtschaf...
# 4      Black-Sabbath-Band  [Suche nach Alben von Black Sabbath., Finde Ko...
# ...                   ...                                                ...
# 15361         Klimawandel  [Ermittlung der Ursachen und Auswirkungen des ...
# 15362          Tierschutz  [Ermittlung von Tierschutzproblemen und -lösun...
# 15363             Bildung  [Ermittlung von Bildungschancen und -ungleichh...
# 15364          Gesundheit  [Ermittlung von Gesundheitsrisiken und -gefahr...
# 15365               Kunst  [Ermittlung von Kunststilen und -techniken., I...
#
# [15366 rows x 2 columns]

# %%
df_parsed.drop_duplicates(subset=["topic"])# .sample(4)
# Out:
#                             topic  \
# 0              Star-Wars-Universe
# 1              Heißwassererhitzer
# 2                     Nagelpflege
# 3                      Großbetrug
# 4              Black-Sabbath-Band
# ...                           ...
# 15348  Fusionen und Akquisitionen
# 15349  Tesla Produkte und Dienste
# 15353    Mode und Textilindustrie
# 15357       Wirtschaftssanktionen
# 15360      Lebensmittelsicherheit
#
#                                                questions
# 0      [Suche nach Filmen, in denen Darth Vader vorko...
# 1      [Suche nach Anleitungen zur Installation von B...
# 2      [Suche nach Videotutorials zur Maniküre und Pe...
# 3      [Suche nach Nachrichtenartikeln über Wirtschaf...
# 4      [Suche nach Alben von Black Sabbath., Finde Ko...
# ...                                                  ...
# 15348  [Suche nach Informationen über die Vorteile un...
# 15349  [Suche nach Informationen über die Produktpale...
# 15353  [Suche nach Informationen über Trends und Neuh...
# 15357  [Ermittlung der Auswirkungen von Wirtschaftssa...
# 15360  [Ermittlung von Risiken und Gefahren für die L...
#
# [5141 rows x 2 columns]
